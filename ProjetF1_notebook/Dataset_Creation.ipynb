# %%
import fastf1
from fastf1.livetiming.data import LiveTimingData
import pandas as pd
import numpy as np

# %%
fastf1.Cache.enable_cache(r'C:\Users\benja\OneDrive - De Vinci\S7_ESILV\cach_directory')

# %%
session_letter = ['FP1', 'FP2', 'FP3', 'Q', 'R']
sessions = []
for year in range(2018,2022):
    for gp in range(1,22):
        for l in session_letter:
            try:
                session = fastf1.get_session(year, gp, l)
                sessions.append(session)
            except:
                print("problem on",year, gp, l)
# Out:
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# problem on 2020 18 FP1
# problem on 2020 18 FP2
# problem on 2020 18 FP3
# problem on 2020 18 Q
# problem on 2020 18 R
# problem on 2020 19 FP1
# problem on 2020 19 FP2
# problem on 2020 19 FP3
# problem on 2020 19 Q
# problem on 2020 19 R
# problem on 2020 20 FP1
# problem on 2020 20 FP2
# problem on 2020 20 FP3
# problem on 2020 20 Q
# problem on 2020 20 R
# problem on 2020 21 FP1
# problem on 2020 21 FP2
# problem on 2020 21 FP3
# problem on 2020 21 Q
# problem on 2020 21 R
# problem on 2021 10 FP3
# problem on 2021 14 FP3
# core        WARNING 	Ergast API lookup failed. The session is very recent and not yet available or does not exist.
# problem on 2021 19 FP3
# core        WARNING 	Ergast API lookup failed. The session is very recent and not yet available or does not exist.
# core        WARNING 	Ergast API lookup failed. The session is very recent and not yet available or does not exist.
# core        WARNING 	Ergast API lookup failed. The session is very recent and not yet available or does not exist.

# %%
pd.DataFrame(sessions[1].results).head()
# Out:
#   number position positionText points  \
# 0      5        1            1     25
# 1     44        2            2     18
# 2      7        3            3     15
# 3      3        4            4     12
# 4     14        5            5     10
#
#                                               Driver  \
# 0  {'driverId': 'vettel', 'permanentNumber': '5',...
# 1  {'driverId': 'hamilton', 'permanentNumber': '4...
# 2  {'driverId': 'raikkonen', 'permanentNumber': '...
# 3  {'driverId': 'ricciardo', 'permanentNumber': '...
# 4  {'driverId': 'alonso', 'permanentNumber': '14'...
#
#                                          Constructor grid laps    status  \
# 0  {'constructorId': 'ferrari', 'url': 'http://en...    3   58  Finished
# 1  {'constructorId': 'mercedes', 'url': 'http://e...    1   58  Finished
# 2  {'constructorId': 'ferrari', 'url': 'http://en...    2   58  Finished
# 3  {'constructorId': 'red_bull', 'url': 'http://e...    8   58  Finished
# 4  {'constructorId': 'mclaren', 'url': 'http://en...   10   58  Finished
#
#                                            Time  \
# 0  {'millis': '5373283', 'time': '1:29:33.283'}
# 1       {'millis': '5378319', 'time': '+5.036'}
# 2       {'millis': '5379592', 'time': '+6.309'}
# 3       {'millis': '5380352', 'time': '+7.069'}
# 4      {'millis': '5401169', 'time': '+27.886'}
#
#                                           FastestLap
# 0  {'rank': '4', 'lap': '53', 'Time': {'time': '1...
# 1  {'rank': '3', 'lap': '50', 'Time': {'time': '1...
# 2  {'rank': '2', 'lap': '57', 'Time': {'time': '1...
# 3  {'rank': '1', 'lap': '54', 'Time': {'time': '1...
# 4  {'rank': '7', 'lap': '57', 'Time': {'time': '1...

# %%
l=[]
year = []
gp = []
label_session = []

for elmt in sessions:
    for res in elmt.results:
        l.append(res)
        year.append(elmt.weekend.year)
        gp.append(elmt.weekend.name)
        label_session.append(elmt.name)

# %%
Data = pd.DataFrame(l)
Data['year'] = year 
Data['gpName'] = gp
Data['sessionName'] = label_session
Data.head()
# Out:
#   number position positionText points  \
# 0      5        1            1     25
# 1     44        2            2     18
# 2      7        3            3     15
# 3      3        4            4     12
# 4     14        5            5     10
#
#                                               Driver  \
# 0  {'driverId': 'vettel', 'permanentNumber': '5',...
# 1  {'driverId': 'hamilton', 'permanentNumber': '4...
# 2  {'driverId': 'raikkonen', 'permanentNumber': '...
# 3  {'driverId': 'ricciardo', 'permanentNumber': '...
# 4  {'driverId': 'alonso', 'permanentNumber': '14'...
#
#                                          Constructor grid laps    status  \
# 0  {'constructorId': 'ferrari', 'url': 'http://en...    3   58  Finished
# 1  {'constructorId': 'mercedes', 'url': 'http://e...    1   58  Finished
# 2  {'constructorId': 'ferrari', 'url': 'http://en...    2   58  Finished
# 3  {'constructorId': 'red_bull', 'url': 'http://e...    8   58  Finished
# 4  {'constructorId': 'mclaren', 'url': 'http://en...   10   58  Finished
#
#                                            Time  \
# 0  {'millis': '5373283', 'time': '1:29:33.283'}
# 1       {'millis': '5378319', 'time': '+5.036'}
# 2       {'millis': '5379592', 'time': '+6.309'}
# 3       {'millis': '5380352', 'time': '+7.069'}
# 4      {'millis': '5401169', 'time': '+27.886'}
#
#                                           FastestLap   Q1   Q2   Q3  year  \
# 0  {'rank': '4', 'lap': '53', 'Time': {'time': '1...  NaN  NaN  NaN  2018
# 1  {'rank': '3', 'lap': '50', 'Time': {'time': '1...  NaN  NaN  NaN  2018
# 2  {'rank': '2', 'lap': '57', 'Time': {'time': '1...  NaN  NaN  NaN  2018
# 3  {'rank': '1', 'lap': '54', 'Time': {'time': '1...  NaN  NaN  NaN  2018
# 4  {'rank': '7', 'lap': '57', 'Time': {'time': '1...  NaN  NaN  NaN  2018
#
#                   gpName sessionName
# 0  Australian Grand Prix  Practice 1
# 1  Australian Grand Prix  Practice 1
# 2  Australian Grand Prix  Practice 1
# 3  Australian Grand Prix  Practice 1
# 4  Australian Grand Prix  Practice 1

# %% [markdown]
# ## Driver DATA

# %%
Data_driver = Data['Driver'].apply(pd.Series)
Data_driver.head()
# Out:
#     driverId permanentNumber code  \
# 0     vettel               5  VET
# 1   hamilton              44  HAM
# 2  raikkonen               7  RAI
# 3  ricciardo               3  RIC
# 4     alonso              14  ALO
#
#                                                  url  givenName familyName  \
# 0      http://en.wikipedia.org/wiki/Sebastian_Vettel  Sebastian     Vettel
# 1        http://en.wikipedia.org/wiki/Lewis_Hamilton      Lewis   Hamilton
# 2  http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C...       Kimi  Räikkönen
# 3      http://en.wikipedia.org/wiki/Daniel_Ricciardo     Daniel  Ricciardo
# 4       http://en.wikipedia.org/wiki/Fernando_Alonso   Fernando     Alonso
#
#   dateOfBirth nationality
# 0  1987-07-03      German
# 1  1985-01-07     British
# 2  1979-10-17     Finnish
# 3  1989-07-01  Australian
# 4  1981-07-29     Spanish

# %%
Data_driver_drop = Data_driver.drop(['url','givenName','familyName','dateOfBirth','permanentNumber'],axis=1)

# %%
Data_driver_drop =Data_driver_drop.rename(columns={"nationality": "DriverNationality"})

# %%
Data_driver_drop.head()
# Out:
#     driverId code DriverNationality
# 0     vettel  VET            German
# 1   hamilton  HAM           British
# 2  raikkonen  RAI           Finnish
# 3  ricciardo  RIC        Australian
# 4     alonso  ALO           Spanish

# %% [markdown]
# ## Constructor DATA

# %%
Data_constructor = Data['Constructor'].apply(pd.Series)
Data_constructor.head()
# Out:
#   constructorId                                                url      name  \
# 0       ferrari      http://en.wikipedia.org/wiki/Scuderia_Ferrari   Ferrari
# 1      mercedes  http://en.wikipedia.org/wiki/Mercedes-Benz_in_...  Mercedes
# 2       ferrari      http://en.wikipedia.org/wiki/Scuderia_Ferrari   Ferrari
# 3      red_bull       http://en.wikipedia.org/wiki/Red_Bull_Racing  Red Bull
# 4       mclaren               http://en.wikipedia.org/wiki/McLaren   McLaren
#
#   nationality
# 0     Italian
# 1      German
# 2     Italian
# 3    Austrian
# 4     British

# %%
Data_constructor_drop = Data_constructor.drop(['url','name'],axis=1)

# %%
Data_constructor_drop = Data_constructor_drop.rename(columns={"nationality": "constructorNationality"})

# %%
Data_constructor_drop.head()
# Out:
#   constructorId constructorNationality
# 0       ferrari                Italian
# 1      mercedes                 German
# 2       ferrari                Italian
# 3      red_bull               Austrian
# 4       mclaren                British

# %% [markdown]
# ## Fastest Lap DATA

# %%
Data_fast = Data['FastestLap'].apply(pd.Series)
Data_fast.head()
# Out:
#     0                          AverageSpeed                  Time lap rank
# 0 NaN  {'units': 'kph', 'speed': '220.782'}  {'time': '1:26.469'}  53    4
# 1 NaN  {'units': 'kph', 'speed': '220.845'}  {'time': '1:26.444'}  50    3
# 2 NaN  {'units': 'kph', 'speed': '221.027'}  {'time': '1:26.373'}  57    2
# 3 NaN  {'units': 'kph', 'speed': '222.128'}  {'time': '1:25.945'}  54    1
# 4 NaN  {'units': 'kph', 'speed': '219.489'}  {'time': '1:26.978'}  57    7

# %%
Data_fast = pd.concat([Data_fast.drop(['AverageSpeed'], axis=1), Data_fast['AverageSpeed'].apply(pd.Series)], axis=1)
Data_fast = pd.concat([Data_fast.drop(['Time'], axis=1), Data_fast['Time'].apply(pd.Series)], axis=1)

# %%
Data_fast.columns
# Out:
# Index([0, 'lap', 'rank', 0, 'speed', 'units', 0, 'time'], dtype='object')

# %%
Data_fast_drop = Data_fast.drop([0,'units'],axis=1)

# %%
Data_fast_drop = Data_fast_drop.rename(columns={"lap": "fastestLapNumber","rank":"fastestLapRank","speed":"fastestLapAvgSpeed","time":"fastestLapTime"})

# %%
Data_fast_drop.head()
# Out:
#   fastestLapNumber fastestLapRank fastestLapAvgSpeed fastestLapTime
# 0               53              4            220.782       1:26.469
# 1               50              3            220.845       1:26.444
# 2               57              2            221.027       1:26.373
# 3               54              1            222.128       1:25.945
# 4               57              7            219.489       1:26.978

# %% [markdown]
# ## Time DATA

# %%
Data_time = Data['Time'].apply(pd.Series)
Data_time.head()
# Out:
#     0   millis         time
# 0 NaN  5373283  1:29:33.283
# 1 NaN  5378319       +5.036
# 2 NaN  5379592       +6.309
# 3 NaN  5380352       +7.069
# 4 NaN  5401169      +27.886

# %%
Data_time_drop = Data_time.drop([0],axis=1)

# %%
Data_time_drop = Data_time_drop.rename(columns={"millis": "totalTime","time":"TimeInterval"})

# %%
Data_time_drop.head()
# Out:
#   totalTime TimeInterval
# 0   5373283  1:29:33.283
# 1   5378319       +5.036
# 2   5379592       +6.309
# 3   5380352       +7.069
# 4   5401169      +27.886

# %% [markdown]
# ## Data Concatenation

# %%
df_global = pd.concat([Data.drop(['Driver'], axis=1), Data_driver_drop], axis=1)
df_global = pd.concat([df_global.drop(['Constructor'], axis=1), Data_constructor_drop], axis=1)
df_global = pd.concat([df_global.drop(['FastestLap'], axis=1), Data_fast_drop], axis=1)
df_global = pd.concat([df_global.drop(['Time'], axis=1), Data_time_drop], axis=1)

# %%
df_global.columns
# Out:
# Index(['number', 'position', 'positionText', 'points', 'grid', 'laps',
#        'status', 'Q1', 'Q2', 'Q3', 'year', 'gpName', 'sessionName', 'driverId',
#        'code', 'DriverNationality', 'constructorId', 'constructorNationality',
#        'fastestLapNumber', 'fastestLapRank', 'fastestLapAvgSpeed',
#        'fastestLapTime', 'totalTime', 'TimeInterval'],
#       dtype='object')

# %%
df_global.head()
# Out:
#   number position positionText points grid laps    status   Q1   Q2   Q3  ...  \
# 0      5        1            1     25    3   58  Finished  NaN  NaN  NaN  ...
# 1     44        2            2     18    1   58  Finished  NaN  NaN  NaN  ...
# 2      7        3            3     15    2   58  Finished  NaN  NaN  NaN  ...
# 3      3        4            4     12    8   58  Finished  NaN  NaN  NaN  ...
# 4     14        5            5     10   10   58  Finished  NaN  NaN  NaN  ...
#
#    code DriverNationality constructorId constructorNationality  \
# 0   VET            German       ferrari                Italian
# 1   HAM           British      mercedes                 German
# 2   RAI           Finnish       ferrari                Italian
# 3   RIC        Australian      red_bull               Austrian
# 4   ALO           Spanish       mclaren                British
#
#   fastestLapNumber fastestLapRank fastestLapAvgSpeed fastestLapTime totalTime  \
# 0               53              4            220.782       1:26.469   5373283
# 1               50              3            220.845       1:26.444   5378319
# 2               57              2            221.027       1:26.373   5379592
# 3               54              1            222.128       1:25.945   5380352
# 4               57              7            219.489       1:26.978   5401169
#
#   TimeInterval
# 0  1:29:33.283
# 1       +5.036
# 2       +6.309
# 3       +7.069
# 4      +27.886
#
# [5 rows x 24 columns]

# %%
df_global.shape
# Out:
# (7937, 24)

# %%
sessions[1].name
# Out:
# 'Practice 2'

# %%
len(year)
# Out:
# 7937

# %%
len(gp)
# Out:
# 7937

# %%
df_global[df_global['sessionName']== 'Practice 1'].head(50)
# Out:
#     number position positionText points grid laps      status   Q1   Q2   Q3  \
# 0        5        1            1     25    3   58    Finished  NaN  NaN  NaN
# 1       44        2            2     18    1   58    Finished  NaN  NaN  NaN
# 2        7        3            3     15    2   58    Finished  NaN  NaN  NaN
# 3        3        4            4     12    8   58    Finished  NaN  NaN  NaN
# 4       14        5            5     10   10   58    Finished  NaN  NaN  NaN
# 5       33        6            6      8    4   58    Finished  NaN  NaN  NaN
# 6       27        7            7      6    7   58    Finished  NaN  NaN  NaN
# 7       77        8            8      4   15   58    Finished  NaN  NaN  NaN
# 8        2        9            9      2   11   58    Finished  NaN  NaN  NaN
# 9       55       10           10      1    9   58    Finished  NaN  NaN  NaN
# 10      11       11           11      0   12   58    Finished  NaN  NaN  NaN
# 11      31       12           12      0   14   58    Finished  NaN  NaN  NaN
# 12      16       13           13      0   18   58    Finished  NaN  NaN  NaN
# 13      18       14           14      0   13   58    Finished  NaN  NaN  NaN
# 14      28       15           15      0   16   57      +1 Lap  NaN  NaN  NaN
# 15       8       16            R      0    6   24       Wheel  NaN  NaN  NaN
# 16      20       17            R      0    5   22       Wheel  NaN  NaN  NaN
# 17      10       18            R      0   20   13      Engine  NaN  NaN  NaN
# 18       9       19            R      0   17    5    Steering  NaN  NaN  NaN
# 19      35       20            R      0   19    4      Brakes  NaN  NaN  NaN
# 100      5        1            1     25    1   57    Finished  NaN  NaN  NaN
# 101     77        2            2     18    3   57    Finished  NaN  NaN  NaN
# 102     44        3            3     15    9   57    Finished  NaN  NaN  NaN
# 103     10        4            4     12    5   57    Finished  NaN  NaN  NaN
# 104     20        5            5     10    6   57    Finished  NaN  NaN  NaN
# 105     27        6            6      8    7   57    Finished  NaN  NaN  NaN
# 106     14        7            7      6   13   56      +1 Lap  NaN  NaN  NaN
# 107      2        8            8      4   14   56      +1 Lap  NaN  NaN  NaN
# 108      9        9            9      2   17   56      +1 Lap  NaN  NaN  NaN
# 109     31       10           10      1    8   56      +1 Lap  NaN  NaN  NaN
# 110     55       11           11      0   10   56      +1 Lap  NaN  NaN  NaN
# 111     16       12           12      0   19   56      +1 Lap  NaN  NaN  NaN
# 112      8       13           13      0   16   56      +1 Lap  NaN  NaN  NaN
# 113     18       14           14      0   20   56      +1 Lap  NaN  NaN  NaN
# 114     35       15           15      0   18   56      +1 Lap  NaN  NaN  NaN
# 115     11       16           16      0   12   56      +1 Lap  NaN  NaN  NaN
# 116     28       17           17      0   11   56      +1 Lap  NaN  NaN  NaN
# 117      7       18            R      0    2   35       Wheel  NaN  NaN  NaN
# 118     33       19            R      0   15    3    Puncture  NaN  NaN  NaN
# 119      3       20            R      0    4    1  Electrical  NaN  NaN  NaN
# 200      3        1            1     25    6   56    Finished  NaN  NaN  NaN
# 201     77        2            2     18    3   56    Finished  NaN  NaN  NaN
# 202      7        3            3     15    2   56    Finished  NaN  NaN  NaN
# 203     44        4            4     12    4   56    Finished  NaN  NaN  NaN
# 204     33        5            5     10    5   56    Finished  NaN  NaN  NaN
# 205     27        6            6      8    7   56    Finished  NaN  NaN  NaN
# 206     14        7            7      6   13   56    Finished  NaN  NaN  NaN
# 207      5        8            8      4    1   56    Finished  NaN  NaN  NaN
# 208     55        9            9      2    9   56    Finished  NaN  NaN  NaN
# 209     20       10           10      1   11   56    Finished  NaN  NaN  NaN
#
#      ...  code DriverNationality constructorId constructorNationality  \
# 0    ...   VET            German       ferrari                Italian
# 1    ...   HAM           British      mercedes                 German
# 2    ...   RAI           Finnish       ferrari                Italian
# 3    ...   RIC        Australian      red_bull               Austrian
# 4    ...   ALO           Spanish       mclaren                British
# 5    ...   VER             Dutch      red_bull               Austrian
# 6    ...   HUL            German       renault                 French
# 7    ...   BOT           Finnish      mercedes                 German
# 8    ...   VAN           Belgian       mclaren                British
# 9    ...   SAI           Spanish       renault                 French
# 10   ...   PER           Mexican   force_india                 Indian
# 11   ...   OCO            French   force_india                 Indian
# 12   ...   LEC        Monegasque        sauber                  Swiss
# 13   ...   STR          Canadian      williams                British
# 14   ...   HAR     New Zealander    toro_rosso                Italian
# 15   ...   GRO            French          haas               American
# 16   ...   MAG            Danish          haas               American
# 17   ...   GAS            French    toro_rosso                Italian
# 18   ...   ERI           Swedish        sauber                  Swiss
# 19   ...   SIR           Russian      williams                British
# 100  ...   VET            German       ferrari                Italian
# 101  ...   BOT           Finnish      mercedes                 German
# 102  ...   HAM           British      mercedes                 German
# 103  ...   GAS            French    toro_rosso                Italian
# 104  ...   MAG            Danish          haas               American
# 105  ...   HUL            German       renault                 French
# 106  ...   ALO           Spanish       mclaren                British
# 107  ...   VAN           Belgian       mclaren                British
# 108  ...   ERI           Swedish        sauber                  Swiss
# 109  ...   OCO            French   force_india                 Indian
# 110  ...   SAI           Spanish       renault                 French
# 111  ...   LEC        Monegasque        sauber                  Swiss
# 112  ...   GRO            French          haas               American
# 113  ...   STR          Canadian      williams                British
# 114  ...   SIR           Russian      williams                British
# 115  ...   PER           Mexican   force_india                 Indian
# 116  ...   HAR     New Zealander    toro_rosso                Italian
# 117  ...   RAI           Finnish       ferrari                Italian
# 118  ...   VER             Dutch      red_bull               Austrian
# 119  ...   RIC        Australian      red_bull               Austrian
# 200  ...   RIC        Australian      red_bull               Austrian
# 201  ...   BOT           Finnish      mercedes                 German
# 202  ...   RAI           Finnish       ferrari                Italian
# 203  ...   HAM           British      mercedes                 German
# 204  ...   VER             Dutch      red_bull               Austrian
# 205  ...   HUL            German       renault                 French
# 206  ...   ALO           Spanish       mclaren                British
# 207  ...   VET            German       ferrari                Italian
# 208  ...   SAI           Spanish       renault                 French
# 209  ...   MAG            Danish          haas               American
#
#     fastestLapNumber fastestLapRank fastestLapAvgSpeed fastestLapTime  \
# 0                 53              4            220.782       1:26.469
# 1                 50              3            220.845       1:26.444
# 2                 57              2            221.027       1:26.373
# 3                 54              1            222.128       1:25.945
# 4                 57              7            219.489       1:26.978
# 5                 54              5            219.737       1:26.880
# 6                 57              9            219.230       1:27.081
# 7                 54              8            219.386       1:27.019
# 8                 57              6            219.540       1:26.958
# 9                 51             12            217.079       1:27.944
# 10                51             11            217.849       1:27.633
# 11                57             10            217.931       1:27.600
# 12                56             15            215.085       1:28.759
# 13                55             14            215.688       1:28.511
# 14                57             13            216.507       1:28.176
# 15                23             16            214.974       1:28.805
# 16                21             17            213.224       1:29.534
# 17                13             18            210.601       1:30.649
# 18                 4             19            207.036       1:32.210
# 19                 3             20            206.224       1:32.573
# 100               21              7            206.274       1:34.453
# 101               22              1            207.842       1:33.740
# 102               51              2            207.371       1:33.953
# 103               46             11            205.382       1:34.863
# 104               29              5            206.549       1:34.327
# 105               50              9            205.807       1:34.667
# 106               47              4            206.898       1:34.168
# 107               30             16            204.803       1:35.131
# 108               26             15            204.885       1:35.093
# 109               38             12            204.993       1:35.043
# 110               35             18            203.937       1:35.535
# 111               35             14            204.924       1:35.075
# 112               44             10            205.759       1:34.689
# 113               40             13            204.961       1:35.058
# 114               47              3            207.151       1:34.053
# 115               32             17            204.513       1:35.266
# 116               42              8            206.034       1:34.563
# 117               22              6            206.527       1:34.337
# 118              NaN            NaN                NaN            NaN
# 119              NaN            NaN                NaN            NaN
# 200               55              1            204.871       1:35.785
# 201               50              6            202.332       1:36.987
# 202               48              3            203.446       1:36.456
# 203               20              4            202.559       1:36.878
# 204               50              2            203.974       1:36.206
# 205               56              5            202.553       1:36.881
# 206               56              7            201.818       1:37.234
# 207               24              9            201.311       1:37.479
# 208               54             11            200.744       1:37.754
# 209               54             14            199.930       1:38.152
#
#     totalTime TimeInterval
# 0     5373283  1:29:33.283
# 1     5378319       +5.036
# 2     5379592       +6.309
# 3     5380352       +7.069
# 4     5401169      +27.886
# 5     5402228      +28.945
# 6     5405954      +32.671
# 7     5407622      +34.339
# 8     5408204      +34.921
# 9     5419005      +45.722
# 10    5420100      +46.817
# 11    5433561    +1:00.278
# 12    5449042    +1:15.759
# 13    5451571    +1:18.288
# 14        NaN          NaN
# 15        NaN          NaN
# 16        NaN          NaN
# 17        NaN          NaN
# 18        NaN          NaN
# 19        NaN          NaN
# 100   5521940  1:32:01.940
# 101   5522639       +0.699
# 102   5528452       +6.512
# 103   5584174    +1:02.234
# 104   5596986    +1:15.046
# 105   5620964    +1:39.024
# 106       NaN          NaN
# 107       NaN          NaN
# 108       NaN          NaN
# 109       NaN          NaN
# 110       NaN          NaN
# 111       NaN          NaN
# 112       NaN          NaN
# 113       NaN          NaN
# 114       NaN          NaN
# 115       NaN          NaN
# 116       NaN          NaN
# 117       NaN          NaN
# 118       NaN          NaN
# 119       NaN          NaN
# 200   5736380  1:35:36.380
# 201   5745274       +8.894
# 202   5746017       +9.637
# 203   5753365      +16.985
# 204   5756816      +20.436
# 205   5757432      +21.052
# 206   5767019      +30.639
# 207   5771666      +35.286
# 208   5772143      +35.763
# 209   5775974      +39.594
#
# [50 rows x 24 columns]
