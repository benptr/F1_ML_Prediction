# %%
import matplotlib.pyplot as plt
import pandas as pd

import fastf1
import fastf1.plotting
from fastf1.core import Laps

# %%
quali = fastf1.get_session(2021, 21, 'Q')

# %%
laps = quali.load_laps(with_telemetry=True)
# Out:
# core           INFO 	Loading laps for Saudi Arabian Grand Prix - Qualifying [v2.1.11]
# api            INFO 	Fetching timing data...
# api            INFO 	Parsing timing data...
# api            INFO 	Fetching timing app data...
# core           INFO 	Processing timing data...
# api            INFO 	Fetching driver list...
# api            INFO 	Fetching session status data...
# api            INFO 	Fetching track status data...
# api            INFO 	Fetching car data...
# api            INFO 	Parsing car data...
# api            INFO 	Fetching position data...
# api            INFO 	Parsing position data...
# api            INFO 	Fetching weather data...
# core           INFO 	Loaded data for 20 drivers: ['11', '16', '22', '9', '99', '7', '44', '18', '63', '3', '5', '6', '55', '47', '31', '4', '33', '10', '14', '77']

# %%
wea = laps.get_weather_data()

# %%
wea
# Out:
#                      Time AirTemp Humidity Pressure Rainfall TrackTemp  \
# 16 0 days 00:16:35.325000      28     72.2   1013.6     True      31.1
# 18 0 days 00:18:35.323000      28     71.7   1013.6     True      31.1
# 20 0 days 00:20:35.323000    28.2     71.9   1013.7     True      31.3
# 22 0 days 00:22:35.325000    28.4     71.3   1013.6     True      31.7
# 25 0 days 00:25:35.358000    28.5     70.9   1013.5     True      31.6
# ..                    ...     ...      ...      ...      ...       ...
# 22 0 days 00:22:35.325000    28.4     71.3   1013.6     True      31.7
# 25 0 days 00:25:35.358000    28.5     70.9   1013.5     True      31.6
# 26 0 days 00:26:35.357000    28.5     69.8   1013.7     True      31.6
# 28 0 days 00:28:35.395000    28.4     70.8   1013.8     True      30.8
# 33 0 days 00:33:35.405000    28.3     70.8   1013.7     True      31.4
#
#    WindDirection WindSpeed
# 16           161       0.6
# 18           155       0.5
# 20           162       0.9
# 22           158       1.1
# 25           156       1.2
# ..           ...       ...
# 22           158       1.1
# 25           156       1.2
# 26           156       0.8
# 28           153       0.7
# 33           151       0.8
#
# [359 rows x 8 columns]

# %%
drivers = pd.unique(laps['Driver'])
print(drivers)
# Out:
# ['VER' 'HAM' 'PER' 'TSU' 'GAS' 'BOT' 'LEC' 'SAI' 'OCO' 'NOR' 'ALO' 'GIO'
#  'RAI' 'RIC' 'STR' 'RUS' 'VET' 'LAT' 'MSC' 'MAZ']

# %%
lap_Ham = laps.pick_driver('HAM')
fast_Ham = lap_Ham.pick_fastest()
telh = fast_Ham.get_telemetry()
lap_ve = laps.pick_driver('VER')
fast_ve = lap_ve.pick_fastest()
tele = fast_ve.get_telemetry()

# %%
telh
# Out:
#                        Date            SessionTime DriverAhead  \
# 2   2021-12-04 17:57:12.184 0 days 01:12:12.172000
# 3   2021-12-04 17:57:12.293 0 days 01:12:12.281000
# 4   2021-12-04 17:57:12.399 0 days 01:12:12.387000
# 5   2021-12-04 17:57:12.533 0 days 01:12:12.521000          16
# 6   2021-12-04 17:57:12.619 0 days 01:12:12.607000          16
# ..                      ...                    ...         ...
# 761 2021-12-04 17:58:39.258 0 days 01:13:39.246000          11
# 762 2021-12-04 17:58:39.413 0 days 01:13:39.401000          11
# 763 2021-12-04 17:58:39.478 0 days 01:13:39.466000          11
# 764 2021-12-04 17:58:39.653 0 days 01:13:39.641000          11
# 765 2021-12-04 17:58:39.695 0 days 01:13:39.683000          11
#
#      DistanceToDriverAhead                   Time    RPM  Speed  nGear  \
# 2               523.840556        0 days 00:00:00  11116    308      8
# 3               523.840556 0 days 00:00:00.109000  11134    309      8
# 4               523.840556 0 days 00:00:00.215000  11179    309      8
# 5               523.840556 0 days 00:00:00.349000  11224    310      8
# 6               514.623889 0 days 00:00:00.435000  11232    311      8
# ..                     ...                    ...    ...    ...    ...
# 761            2074.741944 0 days 00:01:27.074000  11054    306      8
# 762            2072.508611 0 days 00:01:27.229000  11096    307      8
# 763            2070.341944 0 days 00:01:27.294000  11105    307      8
# 764            2068.175278 0 days 00:01:27.469000  11114    308      8
# 765            2068.175278 0 days 00:01:27.511000  11132    308      8
#
#      Throttle  Brake  DRS         Source     Distance  RelativeDistance  \
# 2         100      0   12  interpolation     0.067548          0.000011
# 3         100      0   12            car     9.428611          0.001538
# 4         100      0   12            pos    18.540426          0.003025
# 5         100      0   12            car    30.095278          0.004910
# 6         100      0   12            pos    37.549833          0.006126
# ..        ...    ...  ...            ...          ...               ...
# 761       100      0   12            pos  6075.154771          0.991131
# 762       100      0   12            car  6088.386667          0.993289
# 763       100      0   12            pos  6093.942230          0.994196
# 764       100      0   12            car  6108.920000          0.996639
# 765       100      0   12  interpolation  6112.520023          0.997227
#
#       Status     X    Y    Z
# 2    OnTrack -1268  150  118
# 3    OnTrack -1299  238  118
# 4    OnTrack -1330  324  118
# 5    OnTrack -1370  432  117
# 6    OnTrack -1396  502  118
# ..       ...   ...  ...  ...
# 761  OnTrack -1150 -193  118
# 762  OnTrack -1192  -68  118
# 763  OnTrack -1210  -16  118
# 764  OnTrack -1259  126  117
# 765  OnTrack -1271  160  117
#
# [764 rows x 18 columns]

# %%
fig, ax = plt.subplots(figsize = (15,10))
ax.plot(telh['Distance'], telh['RPM'], color = "red")
ax.plot(tele['Distance'], tele['RPM'])

# %%
fig, ax = plt.subplots(figsize = (15,10))
ax.plot(telh['Distance'], telh['Speed'], color = 'red')
ax.plot(tele['Distance'], tele['Speed'])

# %%
fig, ax = plt.subplots(3,1,figsize = (15,10))
ax[0].plot(telh['Time'], telh['Throttle'], color = 'green' )
ax[0].plot(telh['Time'], telh['Brake'], color = 'red' )
ax[1].plot(tele['Time'], tele['Throttle'], color = 'darkgreen')
ax[1].plot(tele['Time'], tele['Brake'], color = 'darkred' )
ax[2].plot(telh['Distance'], telh['nGear'],color = 'red')
ax[2].plot(tele['Distance'], tele['nGear'],color = 'blue')

# %% [markdown]
# fig, ax = plt.subplots(figsize = (15,10))
# ax.plot(telh['X'], telh['Y'], color = 'green' )

# %%
dif = telh['Speed']-tele['Speed']

# %%
def colors(column,p1 = 'green',p2 = 'red', other_color = 'lightgrey'):
    pal = []

    for item in column:
        if item < 0:
            pal.append(p2)
        elif item > 0:
            pal.append(p1)
        else:
            pal.append(other_color)
    return pal

# %%
dif = colors(dif)

# %%
dif
# Out:
# ['green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'lightgrey',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'lightgrey',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'lightgrey',
#  'green',
#  'green',
#  'green',
#  'red',
#  'red',
#  'red',
#  'lightgrey',
#  'green',
#  'green',
#  'green',
#  'green',
#  'lightgrey',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'lightgrey',
#  'lightgrey',
#  'lightgrey',
#  'red',
#  'lightgrey',
#  'lightgrey',
#  'green',
#  'lightgrey',
#  'lightgrey',
#  'lightgrey',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'lightgrey',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'lightgrey',
#  'green',
#  'red',
#  'red',
#  'red',
#  'red',
#  'green',
#  'green',
#  'lightgrey',
#  'red',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'lightgrey',
#  'lightgrey',
#  'lightgrey',
#  'red',
#  'red',
#  'red',
#  'red',
#  'lightgrey',
#  'green',
#  'green',
#  'green',
#  'green',
#  'red',
#  'red',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'lightgrey',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'lightgrey',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'lightgrey',
#  'green',
#  'lightgrey',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'green',
#  'lightgrey',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'lightgrey',
#  'lightgrey',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'lightgrey',
#  'red',
#  'red',
#  'lightgrey',
#  'green',
#  'green',
#  'green',
#  'green',
#  'lightgrey',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'lightgrey',
#  'lightgrey']

# %%
fig, ax = plt.subplots(figsize = (15,15))
for i in range(2,len(telh)):
    ax.scatter(telh.loc[i,'X'], telh.loc[i,'Y'] ,color = dif[i])

# %%
def colors2(column,p1 = 'green',p2 = 'red', other_color = 'lightgrey'):
    pal = []

    for item in column:
        if item == 8:
            pal.append(p2)
        elif item > 8:
            pal.append(p1)
        else:
            pal.append(other_color)
    return pal

# %%
drs = colors2(telh['DRS'])
fig, ax = plt.subplots(figsize = (15,10))
for i in range(2,len(telh)):
    ax.scatter(telh.loc[i,'X'], telh.loc[i,'Y'] ,color = drs[i])

# %%
telh.describe()
# Out:
#                      SessionTime  DistanceToDriverAhead  \
# count                        764             764.000000
# mean   0 days 01:12:55.960815445             651.237621
# std    0 days 00:00:25.305787739             752.722657
# min       0 days 01:12:12.172000               2.271389
# 25%       0 days 01:12:34.099750             206.522083
# 50%       0 days 01:12:55.953500             356.035000
# 75%       0 days 01:13:17.790500             527.901944
# max       0 days 01:13:39.683000            2325.380556
#
#                             Time           RPM       Speed       nGear  \
# count                        764    764.000000  764.000000  764.000000
# mean   0 days 00:00:43.788815445  10965.430628  251.476440    6.442408
# std    0 days 00:00:25.305787739   1042.044151   60.120418    1.571563
# min              0 days 00:00:00   6488.000000   93.000000    3.000000
# 25%       0 days 00:00:21.927750  10759.000000  219.750000    6.000000
# 50%       0 days 00:00:43.781500  11233.000000  261.000000    7.000000
# 75%       0 days 00:01:05.618500  11622.500000  302.000000    8.000000
# max       0 days 00:01:27.511000  12412.000000  325.000000    8.000000
#
#          Throttle       Brake         DRS     Distance  RelativeDistance  \
# count  764.000000  764.000000  764.000000   764.000000        764.000000
# mean    81.863874   10.730366    9.052356  2959.947779          0.482900
# std     33.684603   30.135614    1.783096  1796.684280          0.293120
# min      0.000000    0.000000    8.000000     0.067548          0.000011
# 25%     84.000000    0.000000    8.000000  1340.808015          0.218746
# 50%    100.000000    0.000000    8.000000  2865.229306          0.467448
# 75%    100.000000    0.000000   12.000000  4519.777350          0.737379
# max    100.000000  100.000000   14.000000  6112.520023          0.997227
#
#                  X             Y           Z
# count   764.000000    764.000000  764.000000
# mean  -3446.365183   7992.722513  117.787958
# std    1471.576180   8163.113793    4.970114
# min   -5795.000000  -5641.000000  111.000000
# 25%   -4451.750000   1373.750000  114.000000
# 50%   -3727.500000   7895.000000  117.000000
# 75%   -3080.250000  15002.250000  120.000000
# max      26.000000  21797.000000  135.000000

# %%
telh
# Out:
#                        Date            SessionTime DriverAhead  \
# 2   2021-12-04 17:57:12.184 0 days 01:12:12.172000
# 3   2021-12-04 17:57:12.293 0 days 01:12:12.281000
# 4   2021-12-04 17:57:12.399 0 days 01:12:12.387000
# 5   2021-12-04 17:57:12.533 0 days 01:12:12.521000          16
# 6   2021-12-04 17:57:12.619 0 days 01:12:12.607000          16
# ..                      ...                    ...         ...
# 761 2021-12-04 17:58:39.258 0 days 01:13:39.246000          11
# 762 2021-12-04 17:58:39.413 0 days 01:13:39.401000          11
# 763 2021-12-04 17:58:39.478 0 days 01:13:39.466000          11
# 764 2021-12-04 17:58:39.653 0 days 01:13:39.641000          11
# 765 2021-12-04 17:58:39.695 0 days 01:13:39.683000          11
#
#      DistanceToDriverAhead                   Time    RPM  Speed  nGear  \
# 2               523.840556        0 days 00:00:00  11116    308      8
# 3               523.840556 0 days 00:00:00.109000  11134    309      8
# 4               523.840556 0 days 00:00:00.215000  11179    309      8
# 5               523.840556 0 days 00:00:00.349000  11224    310      8
# 6               514.623889 0 days 00:00:00.435000  11232    311      8
# ..                     ...                    ...    ...    ...    ...
# 761            2074.741944 0 days 00:01:27.074000  11054    306      8
# 762            2072.508611 0 days 00:01:27.229000  11096    307      8
# 763            2070.341944 0 days 00:01:27.294000  11105    307      8
# 764            2068.175278 0 days 00:01:27.469000  11114    308      8
# 765            2068.175278 0 days 00:01:27.511000  11132    308      8
#
#      Throttle  Brake  DRS         Source     Distance  RelativeDistance  \
# 2         100      0   12  interpolation     0.067548          0.000011
# 3         100      0   12            car     9.428611          0.001538
# 4         100      0   12            pos    18.540426          0.003025
# 5         100      0   12            car    30.095278          0.004910
# 6         100      0   12            pos    37.549833          0.006126
# ..        ...    ...  ...            ...          ...               ...
# 761       100      0   12            pos  6075.154771          0.991131
# 762       100      0   12            car  6088.386667          0.993289
# 763       100      0   12            pos  6093.942230          0.994196
# 764       100      0   12            car  6108.920000          0.996639
# 765       100      0   12  interpolation  6112.520023          0.997227
#
#       Status     X    Y    Z
# 2    OnTrack -1268  150  118
# 3    OnTrack -1299  238  118
# 4    OnTrack -1330  324  118
# 5    OnTrack -1370  432  117
# 6    OnTrack -1396  502  118
# ..       ...   ...  ...  ...
# 761  OnTrack -1150 -193  118
# 762  OnTrack -1192  -68  118
# 763  OnTrack -1210  -16  118
# 764  OnTrack -1259  126  117
# 765  OnTrack -1271  160  117
#
# [764 rows x 18 columns]

# %%
race = fastf1.get_session(2021, 18, 'R')

# %%
#race_tel = race.load_telemetry(livedata=None)

# %%
laps_r = race.load_laps(with_telemetry=True)
# Out:
# core           INFO 	Loading laps for Mexico City Grand Prix - Race [v2.1.11]
# api            INFO 	Fetching timing data...
# api            INFO 	Parsing timing data...
# api            INFO 	Fetching timing app data...
# core           INFO 	Processing timing data...
# api            INFO 	Fetching driver list...
# api            INFO 	Fetching session status data...
# api            INFO 	Fetching track status data...
# api            INFO 	Fetching car data...
# api            INFO 	Parsing car data...
# api            INFO 	Fetching position data...
# api            INFO 	Parsing position data...
# api         WARNING 	Driver 241: Position data is incomplete!
# api         WARNING 	Driver 242: Position data is incomplete!
# api         WARNING 	Driver 243: Position data is incomplete!
# api            INFO 	Fetching weather data...
# core           INFO 	Loaded data for 20 drivers: ['11', '16', '22', '9', '99', '7', '44', '18', '63', '3', '5', '6', '55', '47', '31', '4', '33', '10', '14', '77']

# %%
lap_Ham_r = laps_r.pick_driver('HAM')

# %%
lap_Ham_r.columns
# Out:
# Index(['Time', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint', 'PitOutTime',
#        'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'Compound', 'TyreLife',
#        'FreshTyre', 'LapStartTime', 'Team', 'Driver', 'TrackStatus',
#        'IsAccurate', 'LapStartDate'],
#       dtype='object')

# %%
lap_Ham_rt = lap_Ham_r.get_telemetry()

# %%
lap_Ham_rt
# Out:
#                          Date            SessionTime DriverAhead  \
# 2     2021-11-07 19:03:04.837 0 days 01:02:03.441000
# 3     2021-11-07 19:03:04.881 0 days 01:02:03.485000
# 4     2021-11-07 19:03:05.033 0 days 01:02:03.637000
# 5     2021-11-07 19:03:05.101 0 days 01:02:03.705000
# 6     2021-11-07 19:03:05.273 0 days 01:02:03.877000          10
# ...                       ...                    ...         ...
# 51579 2021-11-07 20:42:00.220 0 days 02:40:58.824000
# 51580 2021-11-07 20:42:00.440 0 days 02:40:59.044000
# 51581 2021-11-07 20:42:00.448 0 days 02:40:59.052000
# 51582 2021-11-07 20:42:00.660 0 days 02:40:59.264000
# 51583 2021-11-07 20:42:00.675 0 days 02:40:59.279000
#
#        DistanceToDriverAhead                   Time    RPM  Speed  nGear  \
# 2                   1.096667        0 days 00:00:00   8777      0      1
# 3                   1.096667 0 days 00:00:00.044000   8774      0      1
# 4                   1.096667 0 days 00:00:00.196000   8768      0      1
# 5                   1.096667 0 days 00:00:00.264000   8309      0      1
# 6                   1.096667 0 days 00:00:00.436000   7851      0      1
# ...                      ...                    ...    ...    ...    ...
# 51579             663.524167 0 days 01:38:55.383000  11380    246      6
# 51580             663.524167 0 days 01:38:55.603000  11290    246      6
# 51581             663.524167 0 days 01:38:55.611000  11201    246      6
# 51582             663.524167 0 days 01:38:55.823000  11166    243      6
# 51583             663.524167 0 days 01:38:55.838000  11149    241      6
#
#        Throttle  Brake  DRS         Source       Distance  RelativeDistance  \
# 2            20      0    1  interpolation       0.007559      2.510436e-08
# 3            20      0    1            pos       0.011768      3.908294e-08
# 4            20      0    1            car       0.000000      0.000000e+00
# 5            20      0    1            pos      -0.018426     -6.119566e-08
# 6            21      0    1            car       0.000000      0.000000e+00
# ...         ...    ...  ...            ...            ...               ...
# 51579        73      0    0            pos  301071.562049      9.998951e-01
# 51580        49      0    0            pos  301086.598437      9.999451e-01
# 51581        25      0    0            car  301087.139722      9.999469e-01
# 51582        12      0    0            pos  301101.296846      9.999939e-01
# 51583         6      0    0  interpolation  301102.284887      9.999972e-01
#
#         Status     X     Y      Z
# 2      OnTrack  1793   894  22270
# 3      OnTrack  1794   895  22271
# 4      OnTrack  1794   895  22271
# 5      OnTrack  1794   895  22271
# 6      OnTrack  1793   894  22271
# ...        ...   ...   ...    ...
# 51579  OnTrack  -606  1263  22268
# 51580  OnTrack  -456  1246  22269
# 51581  OnTrack  -450  1245  22269
# 51582  OnTrack  -310  1228  22270
# 51583  OnTrack  -299  1226  22270
#
# [51582 rows x 18 columns]

# %%
fast_Ham_r = lap_Ham_r.pick_fastest()

# %%
fast_Ham_r
# Out:
# Time                      0 days 02:34:17.395000
# DriverNumber                                  44
# LapTime                   0 days 00:01:19.820000
# LapNumber                                     66
# Stint                                          2
# PitOutTime                                   NaT
# PitInTime                                    NaT
# Sector1Time               0 days 00:00:28.323000
# Sector2Time               0 days 00:00:30.775000
# Sector3Time               0 days 00:00:20.722000
# Sector1SessionTime        0 days 02:33:25.898000
# Sector2SessionTime        0 days 02:33:56.673000
# Sector3SessionTime        0 days 02:34:17.395000
# SpeedI1                                      279
# SpeedI2                                      286
# SpeedFL                                      253
# SpeedST                                      327
# Compound                                    HARD
# TyreLife                                      37
# FreshTyre                                   True
# LapStartTime              0 days 02:32:57.575000
# Team                                    Mercedes
# Driver                                       HAM
# TrackStatus                                    1
# IsAccurate                                  True
# LapStartDate          2021-11-07 20:33:58.971000
# Name: 134, dtype: object

# %%
print(race_tel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-62058f02681c> in <module>
# ----> 1 print(race_tel)
#
# NameError: name 'race_tel' is not defined

# %%
test = lap_Ham_r

# %%
test.columns

# %%
fig, ax = plt.subplots(figsize = (15,10))
ax.plot(test['Time'], test['SpeedST'], color = 'red')
