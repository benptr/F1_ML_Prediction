# %%
import fastf1
from fastf1.livetiming.data import LiveTimingData
import pandas as pd
import numpy as np

# %%
fastf1.Cache.enable_cache(r'C:\Users\benja\OneDrive - De Vinci\S7_ESILV\cach_directory')

# %%
session_letter = ['FP1', 'FP2', 'FP3', 'Q', 'R']
sessions = []
for year in range(2014,2021):
    for gp in range(1,22):
        for l in session_letter:
            try:
                session = fastf1.get_session(year, gp, l)
                sessions.append(session)
            except:
                print("problem on",year, gp, l)
# Out:
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# problem on 2014 20 FP1
# problem on 2014 20 FP2
# problem on 2014 20 FP3
# problem on 2014 20 Q
# problem on 2014 20 R
# problem on 2014 21 FP1
# problem on 2014 21 FP2
# problem on 2014 21 FP3
# problem on 2014 21 Q
# problem on 2014 21 R
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# problem on 2015 20 FP1
# problem on 2015 20 FP2
# problem on 2015 20 FP3
# problem on 2015 20 Q
# problem on 2015 20 R
# problem on 2015 21 FP1
# problem on 2015 21 FP2
# problem on 2015 21 FP3
# problem on 2015 21 Q
# problem on 2015 21 R
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# problem on 2017 21 FP1
# problem on 2017 21 FP2
# problem on 2017 21 FP3
# problem on 2017 21 Q
# problem on 2017 21 R
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
# problem on 2020 18 FP1
# problem on 2020 18 FP2
# problem on 2020 18 FP3
# problem on 2020 18 Q
# problem on 2020 18 R
# problem on 2020 19 FP1
# problem on 2020 19 FP2
# problem on 2020 19 FP3
# problem on 2020 19 Q
# problem on 2020 19 R
# problem on 2020 20 FP1
# problem on 2020 20 FP2
# problem on 2020 20 FP3
# problem on 2020 20 Q
# problem on 2020 20 R
# problem on 2020 21 FP1
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# core       CRITICAL 	Failed to load critical data from Ergast!
#
#  Cannot determine the date and name of the event. Cannot proceed!
#
# core       CRITICAL 	list index out of range
# problem on 2020 21 FP2
# problem on 2020 21 FP3
# problem on 2020 21 Q
# problem on 2020 21 R

# %%
pd.DataFrame(sessions[1].results).head()
# Out:
#   number position positionText points  \
# 0      6        1            1     25
# 1     20        2            2     18
# 2     22        3            3     15
# 3     14        4            4     12
# 4     77        5            5     10
#
#                                               Driver  \
# 0  {'driverId': 'rosberg', 'permanentNumber': '6'...
# 1  {'driverId': 'kevin_magnussen', 'permanentNumb...
# 2  {'driverId': 'button', 'permanentNumber': '22'...
# 3  {'driverId': 'alonso', 'permanentNumber': '14'...
# 4  {'driverId': 'bottas', 'permanentNumber': '77'...
#
#                                          Constructor grid laps    status  \
# 0  {'constructorId': 'mercedes', 'url': 'http://e...    3   57  Finished
# 1  {'constructorId': 'mclaren', 'url': 'http://en...    4   57  Finished
# 2  {'constructorId': 'mclaren', 'url': 'http://en...   10   57  Finished
# 3  {'constructorId': 'ferrari', 'url': 'http://en...    5   57  Finished
# 4  {'constructorId': 'williams', 'url': 'http://e...   15   57  Finished
#
#                                            Time  \
# 0  {'millis': '5578710', 'time': '1:32:58.710'}
# 1      {'millis': '5605487', 'time': '+26.777'}
# 2      {'millis': '5608737', 'time': '+30.027'}
# 3      {'millis': '5613994', 'time': '+35.284'}
# 4      {'millis': '5626349', 'time': '+47.639'}
#
#                                           FastestLap
# 0  {'rank': '1', 'lap': '19', 'Time': {'time': '1...
# 1  {'rank': '6', 'lap': '49', 'Time': {'time': '1...
# 2  {'rank': '5', 'lap': '39', 'Time': {'time': '1...
# 3  {'rank': '7', 'lap': '57', 'Time': {'time': '1...
# 4  {'rank': '3', 'lap': '56', 'Time': {'time': '1...

# %%
l=[]
year = []
gp = []
label_session = []

for elmt in sessions:
    for res in elmt.results:
        l.append(res)
        year.append(elmt.weekend.year)
        gp.append(elmt.weekend.name)
        label_session.append(elmt.name)

# %%
Data = pd.DataFrame(l)
Data['year'] = year 
Data['gpName'] = gp
Data['sessionName'] = label_session
Data.head()
# Out:
#   number position positionText points  \
# 0      6        1            1     25
# 1     20        2            2     18
# 2     22        3            3     15
# 3     14        4            4     12
# 4     77        5            5     10
#
#                                               Driver  \
# 0  {'driverId': 'rosberg', 'permanentNumber': '6'...
# 1  {'driverId': 'kevin_magnussen', 'permanentNumb...
# 2  {'driverId': 'button', 'permanentNumber': '22'...
# 3  {'driverId': 'alonso', 'permanentNumber': '14'...
# 4  {'driverId': 'bottas', 'permanentNumber': '77'...
#
#                                          Constructor grid laps    status  \
# 0  {'constructorId': 'mercedes', 'url': 'http://e...    3   57  Finished
# 1  {'constructorId': 'mclaren', 'url': 'http://en...    4   57  Finished
# 2  {'constructorId': 'mclaren', 'url': 'http://en...   10   57  Finished
# 3  {'constructorId': 'ferrari', 'url': 'http://en...    5   57  Finished
# 4  {'constructorId': 'williams', 'url': 'http://e...   15   57  Finished
#
#                                            Time  \
# 0  {'millis': '5578710', 'time': '1:32:58.710'}
# 1      {'millis': '5605487', 'time': '+26.777'}
# 2      {'millis': '5608737', 'time': '+30.027'}
# 3      {'millis': '5613994', 'time': '+35.284'}
# 4      {'millis': '5626349', 'time': '+47.639'}
#
#                                           FastestLap   Q1   Q2   Q3  year  \
# 0  {'rank': '1', 'lap': '19', 'Time': {'time': '1...  NaN  NaN  NaN  2014
# 1  {'rank': '6', 'lap': '49', 'Time': {'time': '1...  NaN  NaN  NaN  2014
# 2  {'rank': '5', 'lap': '39', 'Time': {'time': '1...  NaN  NaN  NaN  2014
# 3  {'rank': '7', 'lap': '57', 'Time': {'time': '1...  NaN  NaN  NaN  2014
# 4  {'rank': '3', 'lap': '56', 'Time': {'time': '1...  NaN  NaN  NaN  2014
#
#                   gpName sessionName
# 0  Australian Grand Prix  Practice 1
# 1  Australian Grand Prix  Practice 1
# 2  Australian Grand Prix  Practice 1
# 3  Australian Grand Prix  Practice 1
# 4  Australian Grand Prix  Practice 1

# %% [markdown]
# ## Driver DATA

# %%
Data_driver = Data['Driver'].apply(pd.Series)
Data_driver.head()
# Out:
#           driverId permanentNumber code  \
# 0          rosberg               6  ROS
# 1  kevin_magnussen              20  MAG
# 2           button              22  BUT
# 3           alonso              14  ALO
# 4           bottas              77  BOT
#
#                                             url givenName familyName  \
# 0     http://en.wikipedia.org/wiki/Nico_Rosberg      Nico    Rosberg
# 1  http://en.wikipedia.org/wiki/Kevin_Magnussen     Kevin  Magnussen
# 2    http://en.wikipedia.org/wiki/Jenson_Button    Jenson     Button
# 3  http://en.wikipedia.org/wiki/Fernando_Alonso  Fernando     Alonso
# 4  http://en.wikipedia.org/wiki/Valtteri_Bottas  Valtteri     Bottas
#
#   dateOfBirth nationality
# 0  1985-06-27      German
# 1  1992-10-05      Danish
# 2  1980-01-19     British
# 3  1981-07-29     Spanish
# 4  1989-08-28     Finnish

# %%
Data_driver_drop = Data_driver.drop(['url','givenName','familyName','dateOfBirth','permanentNumber'],axis=1)

# %%
Data_driver_drop =Data_driver_drop.rename(columns={"nationality": "DriverNationality"})

# %%
Data_driver_drop.head()
# Out:
#           driverId code DriverNationality
# 0          rosberg  ROS            German
# 1  kevin_magnussen  MAG            Danish
# 2           button  BUT           British
# 3           alonso  ALO           Spanish
# 4           bottas  BOT           Finnish

# %% [markdown]
# ## Constructor DATA

# %%
Data_constructor = Data['Constructor'].apply(pd.Series)
Data_constructor.head()
# Out:
#   constructorId                                                url      name  \
# 0      mercedes  http://en.wikipedia.org/wiki/Mercedes-Benz_in_...  Mercedes
# 1       mclaren               http://en.wikipedia.org/wiki/McLaren   McLaren
# 2       mclaren               http://en.wikipedia.org/wiki/McLaren   McLaren
# 3       ferrari      http://en.wikipedia.org/wiki/Scuderia_Ferrari   Ferrari
# 4      williams  http://en.wikipedia.org/wiki/Williams_Grand_Pr...  Williams
#
#   nationality
# 0      German
# 1     British
# 2     British
# 3     Italian
# 4     British

# %%
Data_constructor_drop = Data_constructor.drop(['url','name'],axis=1)

# %%
Data_constructor_drop = Data_constructor_drop.rename(columns={"nationality": "constructorNationality"})

# %%
Data_constructor_drop.head()
# Out:
#   constructorId constructorNationality
# 0      mercedes                 German
# 1       mclaren                British
# 2       mclaren                British
# 3       ferrari                Italian
# 4      williams                British

# %% [markdown]
# ## Fastest Lap DATA

# %%
Data_fast = Data['FastestLap'].apply(pd.Series)
Data_fast.head()
# Out:
#     0                          AverageSpeed                  Time lap rank
# 0 NaN  {'units': 'kph', 'speed': '206.436'}  {'time': '1:32.478'}  19    1
# 1 NaN  {'units': 'kph', 'speed': '205.131'}  {'time': '1:33.066'}  49    6
# 2 NaN  {'units': 'kph', 'speed': '205.460'}  {'time': '1:32.917'}  39    5
# 3 NaN  {'units': 'kph', 'speed': '204.867'}  {'time': '1:33.186'}  57    7
# 4 NaN  {'units': 'kph', 'speed': '206.128'}  {'time': '1:32.616'}  56    3

# %%
Data_fast = pd.concat([Data_fast.drop(['AverageSpeed'], axis=1), Data_fast['AverageSpeed'].apply(pd.Series)], axis=1)
Data_fast = pd.concat([Data_fast.drop(['Time'], axis=1), Data_fast['Time'].apply(pd.Series)], axis=1)

# %%
Data_fast.columns
# Out:
# Index([0, 'lap', 'rank', 0, 'speed', 'units', 0, 'time'], dtype='object')

# %%
Data_fast_drop = Data_fast.drop([0,'units'],axis=1)

# %%
Data_fast_drop = Data_fast_drop.rename(columns={"lap": "fastestLapNumber","rank":"fastestLapRank","speed":"fastestLapAvgSpeed","time":"fastestLapTime"})

# %%
Data_fast_drop.head()
# Out:
#   fastestLapNumber fastestLapRank fastestLapAvgSpeed fastestLapTime
# 0               19              1            206.436       1:32.478
# 1               49              6            205.131       1:33.066
# 2               39              5            205.460       1:32.917
# 3               57              7            204.867       1:33.186
# 4               56              3            206.128       1:32.616

# %% [markdown]
# ## Time DATA

# %%
Data_time = Data['Time'].apply(pd.Series)
Data_time.head()
# Out:
#     0   millis         time
# 0 NaN  5578710  1:32:58.710
# 1 NaN  5605487      +26.777
# 2 NaN  5608737      +30.027
# 3 NaN  5613994      +35.284
# 4 NaN  5626349      +47.639

# %%
Data_time_drop = Data_time.drop([0],axis=1)

# %%
Data_time_drop = Data_time_drop.rename(columns={"millis": "totalTime","time":"TimeInterval"})

# %%
Data_time_drop.head()
# Out:
#   totalTime TimeInterval
# 0   5578710  1:32:58.710
# 1   5605487      +26.777
# 2   5608737      +30.027
# 3   5613994      +35.284
# 4   5626349      +47.639

# %% [markdown]
# ## Data Concatenation

# %%
df_global = pd.concat([Data.drop(['Driver'], axis=1), Data_driver_drop], axis=1)
df_global = pd.concat([df_global.drop(['Constructor'], axis=1), Data_constructor_drop], axis=1)
df_global = pd.concat([df_global.drop(['FastestLap'], axis=1), Data_fast_drop], axis=1)
df_global = pd.concat([df_global.drop(['Time'], axis=1), Data_time_drop], axis=1)

# %%
df_global.columns
# Out:
# Index(['number', 'position', 'positionText', 'points', 'grid', 'laps',
#        'status', 'Q1', 'Q2', 'Q3', 'year', 'gpName', 'sessionName', 'driverId',
#        'code', 'DriverNationality', 'constructorId', 'constructorNationality',
#        'fastestLapNumber', 'fastestLapRank', 'fastestLapAvgSpeed',
#        'fastestLapTime', 'totalTime', 'TimeInterval'],
#       dtype='object')

# %%
df_global.head()
# Out:
#   number position positionText points grid laps    status   Q1   Q2   Q3  ...  \
# 0      6        1            1     25    3   57  Finished  NaN  NaN  NaN  ...
# 1     20        2            2     18    4   57  Finished  NaN  NaN  NaN  ...
# 2     22        3            3     15   10   57  Finished  NaN  NaN  NaN  ...
# 3     14        4            4     12    5   57  Finished  NaN  NaN  NaN  ...
# 4     77        5            5     10   15   57  Finished  NaN  NaN  NaN  ...
#
#    code DriverNationality constructorId constructorNationality  \
# 0   ROS            German      mercedes                 German
# 1   MAG            Danish       mclaren                British
# 2   BUT           British       mclaren                British
# 3   ALO           Spanish       ferrari                Italian
# 4   BOT           Finnish      williams                British
#
#   fastestLapNumber fastestLapRank fastestLapAvgSpeed fastestLapTime totalTime  \
# 0               19              1            206.436       1:32.478   5578710
# 1               49              6            205.131       1:33.066   5605487
# 2               39              5            205.460       1:32.917   5608737
# 3               57              7            204.867       1:33.186   5613994
# 4               56              3            206.128       1:32.616   5626349
#
#   TimeInterval
# 0  1:32:58.710
# 1      +26.777
# 2      +30.027
# 3      +35.284
# 4      +47.639
#
# [5 rows x 24 columns]

# %%
df_global.shape
# Out:
# (14120, 24)

# %%
sessions[1].name
# Out:
# 'Practice 2'

# %%
len(year)
# Out:
# 14120

# %%
len(gp)
# Out:
# 14120
